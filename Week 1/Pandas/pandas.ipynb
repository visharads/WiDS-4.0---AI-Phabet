# %%
import pandas as pd

# %%
data = pd.DataFrame({'Country': ['Russia','Colombia','Chile','Equador','Nigeria', 'India'],
                    'Rank':[121,40,100,130,11, 60]})
data
# Out:
#     Country  Rank
# 0    Russia   121
# 1  Colombia    40
# 2     Chile   100
# 3   Equador   130
# 4   Nigeria    11
# 5     India    60

# %%
print(data)
# Out:
#     Country  Rank
# 0    Russia   121
# 1  Colombia    40
# 2     Chile   100
# 3   Equador   130
# 4   Nigeria    11
# 5     India    60

# %%
data.describe()
# Out:
#              Rank
# count    6.000000
# mean    77.000000
# std     47.514208
# min     11.000000
# 25%     45.000000
# 50%     80.000000
# 75%    115.750000
# max    130.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  6 non-null      object
#  1   Rank     6 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 228.0+ bytes

# %%
data = pd.DataFrame({'group':['a', 'a', 'a', 'b','b', 'b', 'c', 'c','c'],'ounces':[4, 3, 12, 6, 8.5, 8, 9, 2, 6]})
data
# Out:
#   group  ounces
# 0     a     4.0
# 1     a     3.0
# 2     a    12.0
# 3     b     6.0
# 4     b     8.5
# 5     b     8.0
# 6     c     9.0
# 7     c     2.0
# 8     c     6.0

# %%
data.sort_values(by=['ounces'], ascending = True, inplace = False)
# Out:
#   group  ounces
# 7     c     2.0
# 1     a     3.0
# 0     a     4.0
# 3     b     6.0
# 8     c     6.0
# 5     b     8.0
# 4     b     8.5
# 6     c     9.0
# 2     a    12.0

# %%
data
# Out:
#   group  ounces
# 0     a     4.0
# 1     a     3.0
# 2     a    12.0
# 3     b     6.0
# 4     b     8.5
# 5     b     8.0
# 6     c     9.0
# 7     c     2.0
# 8     c     6.0

# %%
data.sort_values(by=['group', 'ounces'], ascending = [True, False], inplace = False)
# Out:
#   group  ounces
# 2     a    12.0
# 0     a     4.0
# 1     a     3.0
# 4     b     8.5
# 5     b     8.0
# 3     b     6.0
# 6     c     9.0
# 8     c     6.0
# 7     c     2.0

# %%
help(data.drop_duplicates)
# Out:
# Help on method drop_duplicates in module pandas.core.frame:
#
# drop_duplicates(subset: 'Hashable | Sequence[Hashable] | None' = None, *, keep: 'DropKeep' = 'first', inplace: 'bool' = False, ignore_index: 'bool' = False) -> 'DataFrame | None' method of pandas.core.frame.DataFrame instance
#     Return DataFrame with duplicate rows removed.
#
#     Considering certain columns is optional. Indexes, including time indexes
#     are ignored.
#
#     Parameters
#     ----------
#     subset : column label or sequence of labels, optional
#         Only consider certain columns for identifying duplicates, by
#         default use all of the columns.
#     keep : {'first', 'last', ``False``}, default 'first'
#         Determines which duplicates (if any) to keep.
#
#         - 'first' : Drop duplicates except for the first occurrence.
#         - 'last' : Drop duplicates except for the last occurrence.
#         - ``False`` : Drop all duplicates.
#
#     inplace : bool, default ``False``
# ...

# %%
data = pd.DataFrame({'k1':['one']*3 + ['two']*4, 'k2':[3,2,1,3,3,4,4]})

# %%
data.drop_duplicates(subset = 'k2')
# Out:
#     k1  k2
# 0  one   3
# 1  one   2
# 2  one   1
# 5  two   4

# %%
data
# Out:
#     k1  k2
# 0  one   3
# 1  one   2
# 2  one   1
# 3  two   3
# 4  two   3
# 5  two   4
# 6  two   4

# %%
def myfunc(n):
  return len(n)

x = map(myfunc, ('apple', 'banana', 'cherry'))
x

# %%
data['k1']
# Out:
# 0    one
# 1    one
# 2    one
# 3    two
# 4    two
# 5    two
# 6    two
# Name: k1, dtype: object

# %%
type(data['k1'])
# Out:
# pandas.core.series.Series
